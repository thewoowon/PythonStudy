# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = pd.DataFrame(np.random.randn(4,4),columns=[['1','2','3','4']])

print(data1)

x = [1,2,3,4,5,6]
y = [1,2,3,4,5,6]

plt.plot(data1)
plt.title('First Plt')
plt.xlabel('x')
plt.ylabel('y')



fig,ax = plt.subplots()
ax.plot(data1)
ax.set_title('First Plot')
ax.set_xlabel('x')
ax.set_ylabel('y')
fig.set_dpi(300)
fig.savefig('First_Plot.png')
# Out:
#           1         2         3         4
# 0  0.009194  0.136866 -0.990977 -0.169207
# 1  0.688125 -0.454657 -0.270903  0.070681
# 2 -1.152018 -0.616817  0.577562 -0.155764
# 3  1.006928  1.374331 -0.753244 -0.046089
